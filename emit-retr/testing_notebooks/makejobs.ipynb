# %%
import glob, sys
import subprocess

sys.path.append('../')
from config import CONFIG, LOCS
from REFERENCE_PLANTS import REFERENCE_PLANTS

# %%
def get_header_string(loc_name, prefix, kw_mask='', kmbnd='40' ):
    return f"""#!/bin/bash
#SBATCH --job-name={prefix}_{loc_name}
#SBATCH --output=jobs/out/{prefix}_{loc_name}_%j.out
#SBATCH --error=jobs/out/{prefix}_{loc_name}_%j.err
#SBATCH --time=12:00:00
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=2
#SBATCH --mem=64G

module load miniforge
conda activate nox_env_2

cd /home/kgauld/emit-nox-plumes/emit-retr/

python plot_retrieval_fields.py --loc_name {loc_name} --loc_tick --rgb
"""
# python BATCH_RETR.py --loc_name {loc_name} --skip_done {kw_mask} --km_boundary {kmbnd}
# python EMIT_QUERY.py --loc_name {loc_name} --L2A --L1B --download
# python plot_retrieval_fields.py --loc_name {loc_name} --loc_tick --wind_tick --tv


with open("../targets1", "r") as f:
    target_names = f.read().splitlines()
target_names

# LOCS
# Out:
# ['Colstrip',
#  'Thomas_Hill_Energy_Center',
#  'Labadie',
#  'Ghent',
#  'Mill_Creek',
#  'Laramie_River',
#  'Belews_Creek',
#  'Gerald_Gentleman_Station',
#  'Alcoa_Allowance_Management_Inc',
#  'Martin_Lake',
#  'W_A_Parish',
#  'New_Madrid_Power_Plant',
#  'Shawnee',
#  'Scherer',
#  'Limestone',
#  'Fort_Martin_Power_Station',
#  'Ninemile_Point',
#  'Intermountain']

# %%
# prefix='ALL_RGBPLOT'
# for loc_name in ('RIYADH_PLANT_10', 'RIYADH_PLANT_7', 'RIYADH_QURAYYAH'):
#     hstring = get_header_string(loc_name, prefix)
#     with open(f"../../../jobs/{prefix}_{loc_name}.sh", 'w') as f:
#         f.write(hstring)


# for loc_name in ('XAI_CENTER', 'OPENAI_STARGATE'):
#     hstring = get_header_string(loc_name, prefix, kw_mask='--include_mask', kmbnd='20')
#     with open(f"../../../jobs/{prefix}_{loc_name}.sh", 'w') as f:
#         f.write(hstring)

# %%
prefix='ALL_RGBPLOT'
for loc_name in target_names:
    hstring = get_header_string(loc_name, prefix)
    
    jobfn = f"../../../jobs/{prefix}_{loc_name}.sh"
    with open(jobfn, 'w') as f:
        f.write(hstring)
    # result = subprocess.run(
    #     ["sbatch", jobfn],
    #     capture_output=True,
    #     text=True,
    #     check=True
    # )
    
    # print(result.stdout)

# %%
prefix='ALL'

for loc_name in target_names:
    # if loc_name == 'Laramie_River':
    #     print("skipping Laramie_River")
    #     continue
    result = subprocess.run(
        ["sbatch", f"../../../jobs/{prefix}_{loc_name}.sh"],
        capture_output=True,
        text=True,
        check=True
    )
    
    print(result.stdout)
# Out:
# Submitted batch job 10519218
#
# Submitted batch job 10519219
#
# Submitted batch job 10519220
#
# Submitted batch job 10519221
#
# Submitted batch job 10519222
#
# Submitted batch job 10519223
#
# Submitted batch job 10519224
#
# Submitted batch job 10519225
#
# Submitted batch job 10519226
#
# Submitted batch job 10519227
#
# Submitted batch job 10519228
#
# Submitted batch job 10519229
#
# Submitted batch job 10519230
#
# Submitted batch job 10519231
#
# Submitted batch job 10519232
#
# Submitted batch job 10519233
#
# Submitted batch job 10519234
#
# Submitted batch job 10519235
