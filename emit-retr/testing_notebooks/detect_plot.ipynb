# %%
from IPython.display import Image, display

import glob, sys, os

import numpy as np
import math
import hvplot.xarray
import pandas as pd

import matplotlib.pyplot as plt

from scipy.ndimage import gaussian_filter, distance_transform_edt
from skimage.restoration import denoise_tv_chambolle, inpaint_biharmonic
from datetime import datetime, timedelta, timezone


sys.path.append('../')
from config import CONFIG
from REFERENCE_PLANTS import REFERENCE_PLANTS

sys.path.append('../../datasets/')
from get_geosfp import get_geosfp_wind
from get_hrrr import get_hrrr_wind_10m, get_hrrr_wind_agl
from get_campd import get_emission_rate

sys.path.append('../../EMIT-Data-Resources/python/modules/')
from emit_tools import emit_xarray
help(emit_xarray)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='aa80f9ca-6257-4844-bafb-62f82b20b298'>
#   <div id="f01b3542-f283-4494-bfd8-7ba54424c145" data-root-id="aa80f9ca-6257-4844-bafb-62f82b20b298" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"04c5e649-ccc0-4745-8a73-d78c44657ae6":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"c14c6426-5707-4e16-b25f-1b42519d8a93","attributes":{"notifications":{"type":"object","name":"Notifications","id":"c0c995e0-7daa-4b89-a7ad-a9e2a2cc9d1e"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"aa80f9ca-6257-4844-bafb-62f82b20b298"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"dbc0e82f-33ad-43f0-a09d-d73f326ae2f2","attributes":{"plot_id":"aa80f9ca-6257-4844-bafb-62f82b20b298","comm_id":"0e8c2a571ba6452e858de46987e6823c","client_comm_id":"eacd1d7b2e884acd9cd880a998755e08"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"04c5e649-ccc0-4745-8a73-d78c44657ae6","roots":{"aa80f9ca-6257-4844-bafb-62f82b20b298":"f01b3542-f283-4494-bfd8-7ba54424c145"},"root_ids":["aa80f9ca-6257-4844-bafb-62f82b20b298"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Help on function emit_xarray in module emit_tools:
#
# emit_xarray(filepath, ortho=False, qmask=None, unpacked_bmask=None)
#     This function utilizes other functions in this module to streamline opening an EMIT dataset as an xarray.Dataset.
#
#     Parameters:
#     filepath: a filepath to an EMIT netCDF file
#     ortho: True or False, whether to orthorectify the dataset or leave in crosstrack/downtrack coordinates.
#     qmask: a numpy array output from the quality_mask function used to mask pixels based on quality flags selected in that function. Any non-orthorectified array with the proper crosstrack and downtrack dimensions can also be used.
#     unpacked_bmask: a numpy array from  the band_mask function that can be used to mask band-specific pixels that have been interpolated.
#
#     Returns:
#     out_xr: an xarray.Dataset constructed based on the parameters provided.

# %%
SAVE_COLS = ['LOC_NAME', 'GRANULE', 'LON', 'LAT',
            'GOOD_DATA', 'PLUME',  'CAMPD_RATE',
             'HRRR_AGL_DIR', 'HRRR_AGL_SPD',
             'HRRR_10M_DIR', 'HRRR_10M_SPD',
             'GEOSFP_50M_DIR', 'GEOSFP_50M_SPD']

def get_infodict(loc_name, granule):
    infodict = {}
    for k in SAVE_COLS: infodict[k] = None
    infodict['LOC_NAME'] = loc_name
    infodict['GRANULE'] = granule

    loc_info = REFERENCE_PLANTS[loc_name]
    ltlon, ltlat = loc_info['LON'], loc_info['LAT']
    infodict['LON'], infodict['LAT'] = ltlon, ltlat

    plume_info = RETR_INFO[loc_name]
    if granule in plume_info['WORKED']:
        infodict['PLUME'] = True
        infodict['GOOD_DATA'] = True
    elif granule in plume_info['FAILED']:
        infodict['PLUME'] = False
        infodict['GOOD_DATA'] = True
    else:
        infodict['GOOD_DATA'] = False
        return infodict

    obs_time = datetime.strptime(granule.split('_')[0], "%Y%m%dT%H%M%S").replace(tzinfo=timezone.utc)
    
    geosfp_info = get_geosfp_wind(ltlat, ltlon, obs_time, cache=f'{CONFIG["geosfp"]}/')
    infodict['GEOSFP_50M_DIR'], infodict['GEOSFP_50M_SPD'] = float(geosfp_info["DIR50"]), float(geosfp_info["U50"])
    
    hrrr_agl_info = get_hrrr_wind_agl(ltlat, ltlon, obs_time, layer=(200,600), cache=f'{CONFIG["hrrr"]}')
    infodict['HRRR_AGL_DIR'], infodict['HRRR_AGL_SPD'] = float(hrrr_agl_info["dir_from_deg"]), float(hrrr_agl_info["speed_ms"])
    
    hrrr_10m_info = get_hrrr_wind_10m(ltlat, ltlon, obs_time, cache=f'{CONFIG["hrrr"]}')
    infodict['HRRR_10M_DIR'], infodict['HRRR_10M_SPD'] = float(hrrr_10m_info["dir_from_deg"]), float(hrrr_10m_info["speed_ms"])
    
    infodict['CAMPD_RATE'] = get_emission_rate(loc_info, obs_time, timedelta(hours=4))

    return infodict

# %%
csv_savefn = f"{CONFIG['data_folder']}/metadata.csv"

if os.path.isfile(csv_savefn):
    data = pd.read_csv(csv_savefn)
else:
    data = pd.DataFrame(columns=SAVE_COLS)

for loc_name in RETR_INFO.keys():
    print(loc_name)
    fns = glob.glob(f"{CONFIG['data_folder']}/{loc_name}/*RAD*")
    granules = ['_'.join(k.split('/')[-1].split('_')[4:7]).split('.')[0] for k in fns]
    for g in granules:
        if g in data['GRANULE'].values:
            print(f"already populated {g}, skipping")
            continue
        g_dat = get_infodict(loc_name, g)
        data = pd.concat([data, pd.DataFrame(g_dat, index=[0])])
        data.to_csv(csv_savefn, index=False)
# Out:
# Belews_Creek
# already populated 20250803T153928_2521510_028, skipping
# already populated 20240422T161538_2411311_024, skipping
# already populated 20250813T185258_2522512_035, skipping
# already populated 20240824T151209_2423710_011, skipping
# already populated 20250809T203119_2522113_041, skipping
# already populated 20250523T200416_2514313_029, skipping
# already populated 20240624T151938_2417610_024, skipping
# already populated 20250413T191225_2510312_042, skipping
# Shawnee
# already populated 20240413T201920_2410413_037, skipping
# already populated 20251128T175524_2533211_024, skipping
# already populated 20240728T190920_2421013_025, skipping
# already populated 20240201T174005_2403212_023, skipping
# already populated 20250620T165230_2517111_031, skipping
# already populated 20240326T201356_2408613_021, skipping
# already populated 20250602T165109_2515311_026, skipping
# already populated 20250405T154855_2509510_016, skipping
# already populated 20250927T182600_2527011_025, skipping
# already populated 20240205T160522_2403611_024, skipping
# already populated 20250624T151504_2517510_014, skipping
# already populated 20240223T161027_2405411_010, skipping
# already populated 20250401T172330_2509111_027, skipping
# already populated 20250620T165242_2517111_032, skipping
# Ghent
# already populated 20240521T215636_2414215_006, skipping
# already populated 20240326T201455_2408613_026, skipping
# already populated 20240805T155746_2421811_029, skipping
# already populated 20240418T175308_2410912_035, skipping
# already populated 20250927T182700_2527011_030, skipping
# already populated 20250625T142646_2517609_004, skipping
# already populated 20250621T160425_2517210_028, skipping
# already populated 20251001T165151_2527410_030, skipping
# already populated 20240414T193107_2410513_035, skipping
# already populated 20250927T182648_2527011_029, skipping
# already populated 20240928T183317_2427212_031, skipping
# already populated 20240330T183916_2409012_029, skipping
# already populated 20240805T155734_2421811_028, skipping
# already populated 20240326T201443_2408613_025, skipping
# already populated 20250606T151516_2515710_023, skipping
# already populated 20240801T173249_2421412_031, skipping
# Ninemile_Point
# already populated 20240331T174837_2409112_005, skipping
# already populated 20240806T150710_2421910_004, skipping
# already populated 20251002T160130_2527510_021, skipping
# already populated 20240825T155955_2423810_017, skipping
# already populated 20250414T200042_2510413_035, skipping
# already populated 20250626T151541_2517710_015, skipping
# already populated 20250726T185148_2520712_016, skipping
# already populated 20240621T174325_2417312_047, skipping
# already populated 20231222T174800_2335612_015, skipping
# already populated 20240419T184148_2411012_046, skipping
# already populated 20240929T174236_2427312_012, skipping
# already populated 20231226T161203_2336011_003, skipping
# already populated 20240625T160755_2417711_031, skipping
# already populated 20230403T172921_2309312_002, skipping
# already populated 20240802T164230_2421511_007, skipping
# already populated 20240331T174849_2409112_006, skipping
# already populated 20240404T161230_2409511_009, skipping
# Colstrip
# already populated 20250727T211636_2520814_021, skipping
# already populated 20251003T182648_2527611_024, skipping
# already populated 20240401T201353_2409213_025, skipping
# already populated 20241012T201243_2428613_022, skipping
# already populated 20250407T172513_2509711_005, skipping
# already populated 20240730T204335_2421214_023, skipping
# already populated 20240811T204748_2422414_022, skipping
# already populated 20250407T172525_2509711_006, skipping
# already populated 20240811T204736_2422414_021, skipping
# already populated 20250620T164822_2517111_010, skipping
# already populated 20250608T164919_2515911_022, skipping
# already populated 20250616T182554_2516712_006, skipping
# already populated 20250727T211648_2520814_022, skipping
# already populated 20240815T191038_2422813_023, skipping
# already populated 20250213T190437_2504413_005, skipping
# already populated 20240413T201500_2410413_015, skipping
# already populated 20240803T190800_2421613_023, skipping
# Scherer
# already populated 20250523T200305_2514313_023, skipping
# already populated 20240413T202043_2410413_044, skipping
# already populated 20240722T204750_2420414_015, skipping
# already populated 20230831T135424_2324309_003, skipping
# already populated 20230627T153519_2317810_006, skipping
# already populated 20240223T161201_2405411_018, skipping
# already populated 20230217T185928_2304812_006, skipping
# already populated 20250213T191020_2504413_034, skipping
# already populated 20250620T165405_2517111_039, skipping
# already populated 20250217T173308_2504812_003, skipping
# already populated 20230420T182859_2311012_011, skipping
# Labadie
# already populated 20230401T190639_2309113_015, skipping
# already populated 20230225T154729_2305610_003, skipping
# already populated 20230601T185504_2315213_013, skipping
# already populated 20231001T183824_2327412_015, skipping
# already populated 20240413T201845_2410413_034, skipping
# already populated 20250620T165207_2517111_029, skipping
# already populated 20230528T203308_2314814_017, skipping
# already populated 20240804T164448_2421711_024, skipping
# already populated 20250202T163908_2503311_033, skipping
# already populated 20240927T192024_2427113_024, skipping
# already populated 20240808T150901_2422110_002, skipping
# already populated 20231001T183836_2327412_016, skipping
# already populated 20230927T201419_2327013_015, skipping
# already populated 20231016T193021_2328913_008, skipping
# already populated 20250728T185251_2520912_018, skipping
# already populated 20230405T173159_2309512_015, skipping
# already populated 20250724T203011_2520513_024, skipping
# already populated 20240406T161404_2409711_020, skipping
# already populated 20250728T185302_2520912_019, skipping
# already populated 20250624T151429_2517510_011, skipping
# already populated 20230424T164949_2311411_003, skipping
# already populated 20230808T160742_2322011_016, skipping
# already populated 20240406T161352_2409711_019, skipping
# already populated 20241001T174402_2427512_016, skipping
# already populated 20240223T160951_2405411_007, skipping
# already populated 20251004T160336_2527710_026, skipping
# New_Madrid_Power_Plant
# already populated 20230623T171204_2317411_009, skipping
# already populated 20251128T175512_2533211_023, skipping
# already populated 20230823T170609_2323511_010, skipping
# already populated 20240811T205156_2422414_043, skipping
# already populated 20240205T160510_2403611_023, skipping
# already populated 20250602T165057_2515311_025, skipping
# already populated 20250927T182537_2527011_023, skipping
# already populated 20240815T191458_2422813_045, skipping
# already populated 20241201T171748_2433612_030, skipping
# already populated 20241012T201651_2428613_043, skipping
# already populated 20240201T173953_2403212_022, skipping
# already populated 20240728T190908_2421013_024, skipping
# already populated 20240607T223301_2415915_005, skipping
# already populated 20250721T211833_2520214_027, skipping
# already populated 20250616T183008_2516712_025, skipping
# already populated 20250401T172306_2509111_025, skipping
# already populated 20250401T172318_2509111_026, skipping
# already populated 20250606T151405_2515710_017, skipping
# already populated 20240326T201344_2408613_020, skipping
# already populated 20250927T182549_2527011_024, skipping
# Laramie_River
# already populated 20230801T200818_2321313_017, skipping
# already populated 20230822T175042_2323412_004, skipping
# already populated 20220813T214921_2222514_002, skipping
# already populated 20230801T200806_2321313_016, skipping
# already populated 20250401T185820_2509112_023, skipping
# already populated 20250602T182552_2515312_020, skipping
# already populated 20230609T171248_2316011_017, skipping
# already populated 20230728T214448_2320914_018, skipping
# already populated 20250602T182604_2515312_021, skipping
# already populated 20250529T200221_2514913_021, skipping
# already populated 20250818T175922_2523012_021, skipping
# already populated 20241011T210133_2428514_022, skipping
# already populated 20250615T191514_2516612_022, skipping
# already populated 20240810T213652_2422314_024, skipping
# already populated 20250405T172339_2509511_021, skipping
# already populated 20230818T192541_2323013_003, skipping
# already populated 20250405T172351_2509511_022, skipping
# already populated 20230609T171236_2316011_016, skipping
# already populated 20230814T210006_2322614_004, skipping
# already populated 20230814T210018_2322614_005, skipping
# already populated 20250805T171219_2521711_022, skipping
# already populated 20250328T203618_2508713_022, skipping
# Mill_Creek
# already populated 20230406T164436_2309611_007, skipping
# already populated 20250210T195745_2504113_015, skipping
# already populated 20241002T165613_2427611_026, skipping
# already populated 20230402T181926_2309212_009, skipping
# already populated 20241013T192906_2428713_043, skipping
# already populated 20240805T155722_2421811_027, skipping
# already populated 20240330T183904_2409012_028, skipping
# already populated 20231002T175056_2327512_007, skipping
# already populated 20250617T174148_2516811_022, skipping
# already populated 20240521T215636_2414215_006, skipping
# already populated 20240801T173237_2421412_030, skipping
# already populated 20251001T165139_2527410_029, skipping
# already populated 20250613T191928_2516412_035, skipping
# already populated 20240521T215624_2414215_005, skipping
# already populated 20240403T170259_2409411_031, skipping
# Martin_Lake
# already populated 20250927T182402_2527011_015, skipping
# already populated 20240817T191419_2423013_040, skipping
# already populated 20251128T175337_2533211_015, skipping
# already populated 20240205T160335_2403611_015, skipping
# already populated 20251001T164917_2527410_017, skipping
# already populated 20240924T200619_2426813_021, skipping
# already populated 20241018T184038_2429212_008, skipping
# already populated 20251001T164905_2527410_016, skipping
# already populated 20240128T191250_2402813_015, skipping
# already populated 20250602T164922_2515311_017, skipping
# already populated 20240128T191238_2402813_014, skipping
# already populated 20240225T161125_2405611_012, skipping
# already populated 20240801T173015_2421412_018, skipping
# already populated 20250606T151230_2515710_009, skipping
# already populated 20240728T190733_2421013_016, skipping
# already populated 20241201T171625_2433612_023, skipping
# already populated 20250721T211658_2520214_019, skipping
# already populated 20250622T165208_2517311_035, skipping
# already populated 20250618T182932_2516912_040, skipping
# already populated 20241217T185210_2435212_012, skipping
# already populated 20240326T201210_2408613_012, skipping
# already populated 20240801T173003_2421412_017, skipping
# already populated 20250927T182414_2527011_016, skipping
# already populated 20240201T173818_2403212_014, skipping
# Gerald_Gentleman_Station
# already populated 20230610T162405_2316111_019, skipping
# already populated 20220817T201234_2222913_006, skipping
# already populated 20250623T160106_2517410_012, skipping
# already populated 20220821T183501_2223312_006, skipping
# already populated 20241015T192625_2428913_030, skipping
# already populated 20220821T183449_2223312_005, skipping
# already populated 20230423T173615_2311312_010, skipping
# already populated 20230626T162000_2317711_008, skipping
# already populated 20231015T201651_2328813_009, skipping
# already populated 20240416T192728_2410713_026, skipping
# already populated 20230216T194354_2304713_010, skipping
# already populated 20250623T160054_2517410_011, skipping
# already populated 20230729T205653_2321014_021, skipping
# already populated 20250530T191434_2515013_020, skipping
# already populated 20250619T173827_2517011_024, skipping
# already populated 20240412T210505_2410314_026, skipping
# Alcoa_Allowance_Management_Inc
# already populated 20250420T164808_2511011_024, skipping
# already populated 20240201T174028_2403212_025, skipping
# already populated 20251128T175548_2533211_026, skipping
# already populated 20250412T195846_2510213_036, skipping
# already populated 20251001T165127_2527410_028, skipping
# already populated 20251001T165116_2527410_027, skipping
# already populated 20250609T205631_2516013_034, skipping
# already populated 20240425T152333_2411610_005, skipping
# already populated 20240326T201420_2408613_023, skipping
# already populated 20250401T172341_2509111_028, skipping
# already populated 20250412T195857_2510213_037, skipping
# already populated 20250812T194012_2522413_029, skipping
# already populated 20250602T165133_2515311_028, skipping
# already populated 20250816T180256_2522812_036, skipping
# already populated 20250405T154918_2509510_018, skipping
# already populated 20240627T143027_2417910_002, skipping
# already populated 20250606T151440_2515710_020, skipping
# already populated 20240728T190943_2421013_027, skipping
# already populated 20250927T182624_2527011_027, skipping
# already populated 20240205T160545_2403611_026, skipping
# already populated 20250401T172353_2509111_029, skipping
# already populated 20250405T154907_2509510_017, skipping
# Intermountain
# already populated 20240402T192354_2409313_017, skipping
# already populated 20231001T201146_2327413_013, skipping
# already populated 20231005T183601_2327812_013, skipping
# already populated 20230601T202821_2315214_013, skipping
# already populated 20250613T205135_2516413_017, skipping
# already populated 20230405T190521_2309513_013, skipping
# already populated 20240804T181803_2421712_014, skipping
# already populated 20240406T174711_2409712_013, skipping
# already populated 20250728T202621_2520913_013, skipping
# already populated 20250609T222850_2516014_017, skipping
# already populated 20250816T193520_2522813_017, skipping
# already populated 20230401T204001_2309114_013, skipping
# already populated 20230824T175040_2323612_008, skipping
# already populated 20241005T174121_2427912_013, skipping
# already populated 20230206T180123_2303712_003, skipping
# already populated 20250724T220331_2520514_013, skipping
# already populated 20240212T214534_2404314_009, skipping
# already populated 20241001T191716_2427513_010, skipping
# already populated 20251004T173651_2527711_015, skipping
# already populated 20250202T181228_2503312_014, skipping
# already populated 20240216T200912_2404713_005, skipping
# already populated 20250728T202610_2520913_012, skipping
# already populated 20240402T192342_2409313_016, skipping
# already populated 20230927T214729_2327014_012, skipping
# already populated 20230202T193710_2303313_007, skipping
# already populated 20230328T221506_2308715_013, skipping
# already populated 20230620T193346_2317113_008, skipping
# already populated 20230616T211109_2316714_012, skipping
# already populated 20250820T175830_2523212_017, skipping
# already populated 20230328T221455_2308715_012, skipping
# already populated 20250424T164449_2511411_003, skipping
# already populated 20250420T182035_2511012_017, skipping
# W_A_Parish
# already populated 20231002T174801_2327512_005, skipping
# already populated 20240422T175102_2411312_037, skipping
# already populated 20231006T161211_2327911_005, skipping
# already populated 20241002T165304_2427611_010, skipping
# already populated 20230406T164141_2309611_005, skipping
# already populated 20231221T183610_2335512_012, skipping
# already populated 20250729T180201_2521012_016, skipping
# already populated 20230602T180354_2315312_004, skipping
# already populated 20250809T220638_2522114_034, skipping
# already populated 20231006T161159_2327911_004, skipping
# already populated 20230203T171305_2303412_004, skipping
# already populated 20240624T165506_2417611_037, skipping
# already populated 20241002T165315_2427611_011, skipping
# already populated 20240824T164726_2423711_023, skipping
# already populated 20241006T151744_2428010_016, skipping
# already populated 20231225T165916_2335911_007, skipping
# already populated 20241006T151756_2428010_017, skipping
# already populated 20250413T204754_2510313_040, skipping
# Fort_Martin_Power_Station
# already populated 20250810T194159_2522213_030, skipping
# already populated 20250526T191720_2514613_039, skipping
# already populated 20240621T160640_2417311_031, skipping
# already populated 20240419T170508_2411011_030, skipping
# already populated 20250329T181435_2508812_042, skipping
# already populated 20240821T160031_2423411_018, skipping
# already populated 20250526T191708_2514613_038, skipping
# already populated 20250806T145037_2521810_013, skipping
# already populated 20250810T194210_2522213_031, skipping
# already populated 20240725T200038_2420713_025, skipping
# already populated 20240625T143059_2417710_011, skipping
# already populated 20240621T160629_2417311_030, skipping
