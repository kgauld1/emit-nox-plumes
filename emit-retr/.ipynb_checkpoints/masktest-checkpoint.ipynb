# %%
import earthaccess
import os
import warnings
import csv
import numpy as np
import math
import xarray as xr
import holoviews as hv
import hvplot.xarray
# import netCDF4 as nc
#import cv2 as cv

import glob
import sys
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from scipy import linalg
from lxml import etree
from scipy.ndimage import gaussian_filter, binary_erosion, binary_dilation
from skimage.transform import hough_line, hough_line_peaks

from config import CONFIG, POWER_PLANTS, CROSS_SECTIONS, LOCS
sys.path.append('../EMIT-Data-Resources/python/modules/')
from emit_tools import emit_xarray, ortho_xr
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 26
#      24 from config import CONFIG, POWER_PLANTS, CROSS_SECTIONS, LOCS
#      25 sys.path.append('../EMIT-Data-Resources/python/modules/')
# ---> 26 from emit_tools import emit_xarray, ortho_xr
#
# File /orcd/home/002/kgauld/emit-nox-plumes/emit-retr/../EMIT-Data-Resources/python/modules/emit_tools.py:15
#       1 """
#       2 This Module has the functions related to working with an EMIT dataset. This includes doing things
#       3 like opening and flattening the data to work in xarray, orthorectification, and extracting point and area samples.
#    (...)
#      11 - Update format to match AppEEARS outputs
#      12 """
#      14 # Packages used
# ---> 15 import netCDF4 as nc
#      16 import os
#      17 from spectral.io import envi
#
# ModuleNotFoundError: No module named 'netCDF4'

# %%
# !pip install netCDF4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting netCDF4
#   Downloading netcdf4-1.7.3.tar.gz (836 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 836.1/836.1 kB 8.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [66 lines of output]
#       Collecting Cython>=0.29
#         Downloading cython-3.2.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#                                                     0.0/3.4 MB ? eta -:--:--
#            ━╸                                       0.2/3.4 MB 4.4 MB/s eta 0:00:01
#            ━━━━━━━━━━━╸                             1.0/3.4 MB 13.7 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━            2.5/3.4 MB 25.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 3.4/3.4 MB 26.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 3.4/3.4 MB 26.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 18.1 MB/s eta 0:00:00
#       Collecting numpy>=2.0.0
#         Downloading numpy-2.4.0.tar.gz (20.7 MB)
#                                                     0.0/20.7 MB ? eta -:--:--
#            ━━━━                                     2.2/20.7 MB 66.3 MB/s eta 0:00:01
#            ━━━━━━━━━━╸                              5.6/20.7 MB 80.2 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━╸                         8.1/20.7 MB 77.4 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━                     10.6/20.7 MB 71.8 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━                13.1/20.7 MB 72.5 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━           15.6/20.7 MB 66.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━      18.2/20.7 MB 65.7 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.7/20.7 MB 66.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.7/20.7 MB 66.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.7/20.7 MB 66.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.7/20.7 MB 66.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.7/20.7 MB 66.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.7/20.7 MB 66.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 26.1 MB/s eta 0:00:00
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [19 lines of output]
#             + /home/software/anaconda3/2023.07/bin/python /tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f/vendored-meson/meson/meson.py setup /tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f /tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f/.mesonpy-0gh8pbxz -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f/.mesonpy-0gh8pbxz/meson-python-native-file.ini
#             The Meson build system
#             Version: 1.8.3
#             Source dir: /tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f
#             Build dir: /tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f/.mesonpy-0gh8pbxz
#             Build type: native build
#             Project name: NumPy
#             Project version: 2.4.0
#             C compiler for the host machine: cc (gcc 4.8.5 "cc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)")
#             C linker for the host machine: cc ld.bfd 2.27-44
#             C++ compiler for the host machine: c++ (gcc 4.8.5 "c++ (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)")
#             C++ linker for the host machine: c++ ld.bfd 2.27-44
#             Cython compiler for the host machine: cython (cython 3.2.3)
#             Host machine cpu family: x86_64
#             Host machine cpu: x86_64
#
#             ../meson.build:25:4: ERROR: Problem encountered: NumPy requires GCC >= 9.3
#
#             A full log can be found at /tmp/pip-install-fm9ik_oe/numpy_9043b185e39b4b38b864e67dc342589f/.mesonpy-0gh8pbxz/meson-logs/meson-log.txt
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !ls ../EMIT-Data-Resources/
