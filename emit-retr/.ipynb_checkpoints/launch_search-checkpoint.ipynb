# %%
import os
import earthaccess
import numpy as np
import pandas as pd
import geopandas as gp
from shapely.geometry.polygon import orient
import xarray as xr
import sys

from datetime import timedelta
import numpy as np
import pandas as pd
import glob

sys.path.append('../EMIT-Data-Resources/python/modules/')
from emit_tools import emit_xarray

# %%
auth = earthaccess.login(persist=True)
print(auth.authenticated)
# Out:
# True

# %%
# Retrieve Collections
collections = earthaccess.search_datasets(provider='LPCLOUD', keyword='emit')
# Print Quantity of Results
print(f'Collections found: {len(collections)}')

collections_info = [
    {
        'short_name': c.summary()['short-name'],
        'collection_concept_id': c.summary()['concept-id'],
        'version': c.summary()['version'],
        'entry_title': c['umm']['EntryTitle']
    }
    for c in collections
]
pd.set_option('display.max_colwidth', 150)
collections_info = pd.DataFrame(collections_info)
collections_info
# Out:
# Collections found: 13
#        short_name collection_concept_id version  \
# 0      EMITL2ARFL   C2408750690-LPCLOUD     001
# 1      EMITL1BRAD   C2408009906-LPCLOUD     001
# 2   EMITL2BCH4ENH   C3242680113-LPCLOUD     002
# 3   EMITL2BCH4PLM   C2748088093-LPCLOUD     001
# 4      EMITL2BMIN   C2408034484-LPCLOUD     001
# 5   EMITL2BCH4ENH   C2748097305-LPCLOUD     001
# 6   EMITL2BCO2ENH   C3243477145-LPCLOUD     002
# 7   EMITL2BCO2ENH   C2872578364-LPCLOUD     001
# 8   EMITL2BCO2PLM   C2867824144-LPCLOUD     001
# 9       EMITL4ESM   C2408755900-LPCLOUD     001
# 10     EMITL1BATT   C2408031090-LPCLOUD     001
# 11      EMITL3ASA   C3147269019-LPCLOUD     002
# 12      EMITL3ASA   C2408752948-LPCLOUD     001
#
#                                                                            entry_title
# 0           EMIT L2A Estimated Surface Reflectance and Uncertainty and Masks 60 m V001
# 1                EMIT L1B At-Sensor Calibrated Radiance and Geolocation Data 60 m V001
# 2                                          EMIT L2B Methane Enhancement Data 60 m V002
# 3                                 EMIT L2B Estimated Methane Plume Complexes 60 m V001
# 4   EMIT L2B Estimated Mineral Identification and Band Depth and Uncertainty 60 m V001
# 5                                          EMIT L2B Methane Enhancement Data 60 m V001
# 6                                   EMIT L2B Carbon Dioxide Enhancement Data 60 m V002
# 7                                   EMIT L2B Carbon Dioxide Enhancement Data 60 m V001
# 8                          EMIT L2B Estimated Carbon Dioxide Plume Complexes 60 m V001
# 9                                             EMIT L4 Earth System Model Products V001
# 10                           EMIT L1B Corrected Spacecraft Attitude and Ephemeris V001
# 11          EMIT L3 Aggregated Mineral Spectral Abundance and Uncertainty 0.5 Deg V002
# 12          EMIT L3 Aggregated Mineral Spectral Abundance and Uncertainty 0.5 Deg V001

# %%
#### FROM JOE PALMO


#### planet4589.org data
df = pd.read_csv('https://planet4589.org/space/gcat/tsv/launch/launch.tsv', sep='\t',)
sites_df = pd.read_csv('https://planet4589.org/space/gcat/tsv/tables/sites.tsv', sep='\t')

#### FUNCTIONS
def clean_and_parse_date(date_str):
    try:
        # Remove invalid characters like "?"
        cleaned_date = date_str.replace('?', '').strip()

        # Check if the format includes seconds
        if len(cleaned_date.split()) == 4 and ':' in cleaned_date:
            return pd.to_datetime(cleaned_date, format='%Y %b %d %H%M:%S')
        # Check if the format includes hours and minutes
        elif len(cleaned_date.split()) == 4:
            return pd.to_datetime(cleaned_date, format='%Y %b %d %H%M')
        # Check if it's just year, month, day
        elif len(cleaned_date.split()) == 3:
            return pd.to_datetime(cleaned_date, format='%Y %b %d')
        # Check if it's just year, month 

        ## IGNORE ANYTHING COARSER THAN A DAY
        # elif len(cleaned_date.split()) == 2 and 'Q' not in cleaned_date:
        #     return pd.to_datetime(cleaned_date, format='%Y %b')
        # # Check if it's just year, quarter
        # elif len(cleaned_date.split()) == 2 and 'Q' in cleaned_date:
        #     # Extract the year for quarters
        #     return int(cleaned_date.split()[0])  # Return the year only
        # Check if it's just year
        # elif len(cleaned_date.split()) == 1:
        #     return pd.to_datetime(cleaned_date, format='%Y')
        else:
            return np.nan  # Return NaN for invalid entries
    except Exception:
        return np.nan

# given the Launch_Site, find the corresponding lat and lon
def get_lat(site):
    try:
        return sites_df[sites_df['#Site'] == site]['Latitude'].values[0]
    except Exception:
        return np.nan
    
def get_lon(site):
    try:
        return sites_df[sites_df['#Site'] == site]['Longitude'].values[0]
    except Exception:
        return np.nan

#### DATA CLEANING

def get_launch_df():
    # Apply the cleaning and parsing function
    df['timestamp'] = df['Launch_Date'].apply(clean_and_parse_date)
    df.dropna(subset=['timestamp'], inplace=True)
    # set timestamp index
    df.set_index('timestamp', inplace=True)
    df.index = pd.DatetimeIndex(df.index)
    df.sort_index(inplace=True)

    # only launches during TEMPO mission
    recent_df = df.loc['2023-01-01':]

    # get the lat and lon for each launch site
    recent_df['lat'] = recent_df['Launch_Site'].apply(get_lat).astype(float)
    recent_df['lon'] = recent_df['Launch_Site'].apply(get_lon).astype(float)

    return recent_df

rocket_df = get_launch_df()
rocket_df
# Out:
# /tmp/ipykernel_49080/3718420490.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_df['lat'] = recent_df['Launch_Site'].apply(get_lat).astype(float)
# /tmp/ipykernel_49080/3718420490.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_df['lon'] = recent_df['Launch_Site'].apply(get_lon).astype(float)
#                     #Launch_Tag   Launch_JD           Launch_Date  \
# timestamp
# 2023-01-03 14:55:56   2023-001   2459948.12   2023 Jan  3 1455:56
# 2023-01-08 22:00:00   2023-002   2459953.42      2023 Jan  8 2200
# 2023-01-09 05:04:00   2023-003   2459953.71      2023 Jan  9 0504
# 2023-01-09 23:08:59  2023-F01    2459954.46  2023 Jan  9 2308:59?
# 2023-01-10 04:50:17   2023-004   2459954.70   2023 Jan 10 0450:17
# ...                         ...         ...                   ...
# 2025-09-18 09:30:00   2025-210   2460936.90   2025 Sep 18 0930:00
# 2025-09-18 13:00:07  2025-S43    2460937.04   2025 Sep 18 1300:07
# 2025-09-18 15:00:00  2025-F08    2460937.12     2025 Sep 18 1500?
# 2025-09-19 16:31:39   2025-211   2460938.19   2025 Sep 19 1631:39
# 2025-09-21 10:53:00   2025-212   2460939.95   2025 Sep 21 1053:00
#
#                             LV_Type Variant          Flight_ID  \
# timestamp
# 2023-01-03 14:55:56        Falcon 9     FT5  196/B1060.15 F196
# 2023-01-08 22:00:00  Chang Zheng 7A       -                 Y4
# 2023-01-09 05:04:00    Gushenxing 1       1                 Y5
# 2023-01-09 23:08:59     LauncherOne       -                R07
# 2023-01-10 04:50:17        Falcon 9     FT5  198/B1076.2  F197
# ...                             ...     ...                ...
# 2025-09-18 09:30:00        Falcon 9     FT5  xxx/B1092.7  F535
# 2025-09-18 13:00:07     New Shepard       -           PM4-5 F6
# 2025-09-18 15:00:00        Zoljanah       -                  -
# 2025-09-19 16:31:39        Falcon 9     FT5  xxx/B1088.10 F536
# 2025-09-21 10:53:00        Falcon 9     FT5  xxx/B1085.11 F537
#
#                                Flight               Mission      FlightCode  \
# timestamp
# 2023-01-03 14:55:56     Transporter-6         Transporter-6               -
# 2023-01-08 22:00:00       Shi Jian 23           Shi Jian 23               -
# 2023-01-09 05:04:00      Gime Me Five  Keji-1/Tianmu/Tianqi               -
# 2023-01-09 23:08:59         UK launch           Start Me Up               -
# 2023-01-10 04:50:17          OneWeb-2            OneWeb L16               -
# ...                               ...                   ...             ...
# 2025-09-18 09:30:00      Starlink-305  Starlink Group 10-61      V2MO 10-61
# 2025-09-18 13:00:07  New Shepard NS35   New Shepard CC2.0-1  RSS H.G. Wells
# 2025-09-18 15:00:00             Test?                     -               -
# 2025-09-19 16:31:39      Starlink-306  Starlink Group 17-12      V2MO 17-12
# 2025-09-21 10:53:00      Starlink-307  Starlink Group 10-27      V2MO 10-27
#
#                      Platform  ... Agency LaunchCode FailCode  Group  \
# timestamp                      ...
# 2023-01-03 14:55:56         -  ...    SPX         OS        -      C
# 2023-01-08 22:00:00         -  ...   CALT         OS        -      G
# 2023-01-09 05:04:00         -  ...   XIDO         OS        -      C
# 2023-01-09 23:08:59  B747-744  ...   VORB         OF      S2P   C/OG
# 2023-01-10 04:50:17         -  ...    SPX         OS        -      C
# ...                       ...  ...    ...        ...      ...    ...
# 2025-09-18 09:30:00         -  ...    SPX         OS        -      C
# 2025-09-18 13:00:07         -  ...   BLOR         SS        -  BLOR/
# 2025-09-18 15:00:00         -  ...   IRGC         OF        -      -
# 2025-09-19 16:31:39         -  ...    SPX         OS        -      C
# 2025-09-21 10:53:00         -  ...    SPX         OS        -      C
#
#                            Category               LTCite           Cite  \
# timestamp
# 2023-01-03 14:55:56       Sat SSO D   spaceflightnow.com              -
# 2023-01-08 22:00:00       Sat GTO O  nasaspaceflight.com  xinhuanet.com
# 2023-01-09 05:04:00       Sat SSO D  nasaspaceflight.com              -
# 2023-01-09 23:08:59       Sat LEO L                 Wire              -
# 2023-01-10 04:50:17       Sat LEO D   spaceflightnow.com              -
# ...                             ...                  ...            ...
# 2025-09-18 09:30:00       Sat LEO D        celestrak.org              -
# 2025-09-18 13:00:07  Science Flight  nasaspaceflight.com              -
# 2025-09-18 15:00:00            Test                 Wire              -
# 2025-09-19 16:31:39       Sat SSO D               SpaceX              -
# 2025-09-21 10:53:00       Sat LEO D        celestrak.org              -
#
#                                   Notes      lat       lon
# timestamp
# 2023-01-03 14:55:56                   -  28.4600  -80.5400
# 2023-01-08 22:00:00                   -  19.6142  110.9511
# 2023-01-09 05:04:00                   -  41.3100  100.3100
# 2023-01-09 23:08:59  Fuel feed blockage  50.4408   -5.0076
# 2023-01-10 04:50:17                   -  28.4600  -80.5400
# ...                                 ...      ...       ...
# 2025-09-18 09:30:00                   -  28.4600  -80.5400
# 2025-09-18 13:00:07                   -  31.4228 -104.7572
# 2025-09-18 15:00:00                   -  35.2347   53.9210
# 2025-09-19 16:31:39                   -  34.6300 -120.6100
# 2025-09-21 10:53:00                   -  28.4600  -80.5400
#
# [988 rows x 30 columns]

# %%
# Search example using a Point
results = earthaccess.search_data(
    short_name='EMITL2ARFL',
    point=(-62.1123,-39.89402),
    temporal=('20220903T16','20220903T17'),
    cloud_cover=(0,90),
    count=100
)
results
# Out:
# [Collection: {'ShortName': 'EMITL2ARFL', 'Version': '001'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -62.08873748779297, 'Latitude': -39.2420539855957}, {'Longitude': -62.51200866699219, 'Latitude': -39.943302154541016}, {'Longitude': -61.660133361816406, 'Latitude': -40.45749282836914}, {'Longitude': -61.23686218261719, 'Latitude': -39.75624465942383}, {'Longitude': -62.08873748779297, 'Latitude': -39.2420539855957}]}}]}}}
#  Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2022-09-03T16:31:29Z', 'EndingDateTime': '2022-09-03T16:31:41Z'}}
#  Size(MB): 3578.7448024749756
#  Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20220903T163129_2224611_012/EMIT_L2A_RFL_001_20220903T163129_2224611_012.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20220903T163129_2224611_012/EMIT_L2A_RFLUNCERT_001_20220903T163129_2224611_012.nc', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20220903T163129_2224611_012/EMIT_L2A_MASK_001_20220903T163129_2224611_012.nc']]

# %%
for t, row in rocket_df.iterrows():
    starttime = (t-timedelta(minutes=10)).strftime("%Y%m%dT%H%M")
    endtime = (t+timedelta(hours=2)).strftime("%Y%m%dT%H%M")
    try:
        results = earthaccess.search_data(
            short_name='EMITL1BRAD',
            point=(row['lon'], row['lat']),
            temporal=(starttime, endtime),
            cloud_cover=(0,90),
            count=100
        )
        rocket_df.loc[t, 'emit'] = len(results)
    except:
        rocket_df.loc[t, 'emit'] = -1
    
    # break

# %%
rocket_df.to_csv('rocket_df_withemit_temp.csv')

# %%
emit_df = rocket_df[rocket_df['emit'] == 1]
emit_df
# Out:
#                     #Launch_Tag   Launch_JD          Launch_Date  \
# timestamp
# 2024-08-04 15:02:53   2024-139   2460527.13  2024 Aug  4 1502:53
# 2025-04-03 02:12:00   2025-068   2460768.59     2025 Apr  3 0212
#
#                            LV_Type Variant          Flight_ID          Flight  \
# timestamp
# 2024-08-04 15:02:53       Falcon 9     FT5  367/B1080.10 F361    Cygnus NG-21
# 2025-04-03 02:12:00  Chang Zheng 6       -                Y14  Tianping 3A-02
#
#                             Mission FlightCode Platform  ... LaunchCode  \
# timestamp                                                ...
# 2024-08-04 15:02:53    Cygnus NG-21          -        -  ...         OS
# 2025-04-03 02:12:00  Tianping 3A-02          -        -  ...         OS
#
#                     FailCode Group   Category               LTCite Cite Notes  \
# timestamp
# 2024-08-04 15:02:53        -    CX  Sat ISS D                 Wire    -     -
# 2025-04-03 02:12:00        -     G  Sat SSO D  nasaspaceflight.com    -     -
#
#                        lat     lon  emit
# timestamp
# 2024-08-04 15:02:53  28.46  -80.54   1.0
# 2025-04-03 02:12:00  37.50  112.60   1.0
#
# [2 rows x 31 columns]

# %%
# Get requests https Session using Earthdata Login Info
fs = earthaccess.get_requests_https_session()

for t, row in emit_df.iterrows():
    starttime = (t-timedelta(minutes=10)).strftime("%Y%m%dT%H%M")
    endtime = (t+timedelta(hours=2)).strftime("%Y%m%dT%H%M")
    print(starttime, endtime)
    results = earthaccess.search_data(
            short_name='EMITL1BRAD',
            point=(row['lon'], row['lat']),
            temporal=(starttime, endtime),
            cloud_cover=(0,90),
            count=100
        )
    emit_results_urls = [granule.data_links() for granule in results]
    
    # Retrieve granule asset ID from URL (to maintain existing naming convention)
    for url in emit_results_urls[0]:
        granule_asset_id = url.split('/')[-1]
        # Define Local Filepath
        fp = f'/home/kgauld/orcd/pool/EMIT/{granule_asset_id}'
        # Download the Granule Asset if it doesn't exist
        if not os.path.isfile(fp):
            with fs.get(url,stream=True) as src:
                with open(fp,'wb') as dst:
                    for chunk in src.iter_content(chunk_size=64*1024*1024):
                        dst.write(chunk)
        else:
            print(f"{url} already downloaded. Skipping...")
            continue
        print(f"DOWNLOADED {url} to {fp}")
    # break
# Out:
# 20240804T1452 20240804T1702
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20240804T150747_2421710_013/EMIT_L1B_RAD_001_20240804T150747_2421710_013.nc
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20240804T150747_2421710_013/EMIT_L1B_RAD_001_20240804T150747_2421710_013.nc already downloaded. Skipping...
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20240804T150747_2421710_013/EMIT_L1B_OBS_001_20240804T150747_2421710_013.nc
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20240804T150747_2421710_013/EMIT_L1B_OBS_001_20240804T150747_2421710_013.nc already downloaded. Skipping...
# 20250403T0202 20250403T0412
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20250403T032619_2509302_026/EMIT_L1B_RAD_001_20250403T032619_2509302_026.nc
# DOWNLOADED https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20250403T032619_2509302_026/EMIT_L1B_RAD_001_20250403T032619_2509302_026.nc to /home/kgauld/orcd/pool/EMIT/EMIT_L1B_RAD_001_20250403T032619_2509302_026.nc
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20250403T032619_2509302_026/EMIT_L1B_OBS_001_20250403T032619_2509302_026.nc
# DOWNLOADED https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL1BRAD.001/EMIT_L1B_RAD_001_20250403T032619_2509302_026/EMIT_L1B_OBS_001_20250403T032619_2509302_026.nc to /home/kgauld/orcd/pool/EMIT/EMIT_L1B_OBS_001_20250403T032619_2509302_026.nc

# %%
# !ls /home/kgauld/orcd/pool/EMIT
# Out:
# EMIT_L1B_OBS_001_20240804T150747_2421710_013.nc
# EMIT_L1B_OBS_001_20250403T032619_2509302_026.nc
# EMIT_L1B_RAD_001_20230620T102232_2317107_029.nc
# EMIT_L1B_RAD_001_20240804T150747_2421710_013.nc
# EMIT_L1B_RAD_001_20250403T032619_2509302_026.nc
